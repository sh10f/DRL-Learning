# %% [markdown]
# # PPO_Baseline：FrozenLake-v1

# %%
import gymnasium as gym
import numpy as np
from tqdm import tqdm

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make('FrozenLake-v1', desc=None, map_name="4x4", is_slippery=True)

# Then we reset this environment
observation, info = env.reset()
print("observation: ", observation)
print("info: ", info)

for _ in range(10):
    # Take a random action
    action = env.action_space.sample()
    print("Action taken:", action)
    
    # Do this action in the environment and get
    # next_state, reward, terminated, truncated and info
    observation, reward, terminated, truncated, info = env.step(action)
    print(observation, reward, terminated, truncated, info)
    # If the game is terminated (in our case we land, crashed) or truncated (timeout)
    if terminated or truncated:
      # Reset the environment
      print("Environment is reset")
      observation, info = env.reset()

env.close()
# Out:
# observation:  0
# info:  {'prob': 1}
# Action taken: 3
# 0 0.0 False False {'prob': 0.3333333333333333}
# Action taken: 2
# 0 0.0 False False {'prob': 0.3333333333333333}
# Action taken: 2
# 0 0.0 False False {'prob': 0.3333333333333333}
# Action taken: 2
# 4 0.0 False False {'prob': 0.3333333333333333}
# Action taken: 3
# 0 0.0 False False {'prob': 0.3333333333333333}
# Action taken: 3
# 1 0.0 False False {'prob': 0.3333333333333333}
# Action taken: 1
# 2 0.0 False False {'prob': 0.3333333333333333}
# Action taken: 1
# 3 0.0 False False {'prob': 0.3333333333333333}
# Action taken: 1
# 2 0.0 False False {'prob': 0.3333333333333333}
# Action taken: 2
# 6 0.0 False False {'prob': 0.3333333333333333}

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make('FrozenLake-v1', desc=None, map_name="4x4", is_slippery=True)
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.n)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape 16
# Sample observation 9

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 1

# %%
# Create the environment
# env = gym.make('FrozenLake-v1', desc=None, map_name="4x4", is_slippery=True)
env_args = {
    "desc":None,
    "map_name":"4x4",
    "is_slippery":True
} 
env = make_vec_env('FrozenLake-v1', env_kwargs=env_args, n_envs=16)

# %%
# SOLUTION
# We added some parameters to accelerate the training
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1,
    device="cpu")
# Out:
# Using cpu device

# %%
# SOLUTION
# Train it for 1,000,000 timesteps
model.learn(
    total_timesteps=1000000, 
    progress_bar=True)
# Save the model
model_name = "ppo-FrozenLake-v1"
model.save(model_name)
# Out:
# Output()
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 13.5     |
# |    ep_rew_mean     | 0.15     |
# | time/              |          |
# |    fps             | 3061     |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.6        |
# |    ep_rew_mean          | 0.14        |
# | time/                   |             |
# |    fps                  | 1087        |
# |    iterations           | 2           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008247321 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0348      |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00537    |
# |    value_loss           | 0.0851      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.9         |
# |    ep_rew_mean          | 0.13         |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 3            |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0077680633 |
# |    clip_fraction        | 0.0665       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.917       |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0469       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 0.097        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | 0.29        |
# | time/                   |             |
# |    fps                  | 761         |
# |    iterations           | 4           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005456363 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0161      |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 0.0944      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.5        |
# |    ep_rew_mean          | 0.24        |
# | time/                   |             |
# |    fps                  | 727         |
# |    iterations           | 5           |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007822766 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0297      |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00745    |
# |    value_loss           | 0.111       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.4         |
# |    ep_rew_mean          | 0.27         |
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 6            |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0048943004 |
# |    clip_fraction        | 0.0569       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.662       |
# |    explained_variance   | 0.0856       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0664       |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00461     |
# |    value_loss           | 0.116        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.3         |
# |    ep_rew_mean          | 0.31         |
# | time/                   |              |
# |    fps                  | 682          |
# |    iterations           | 7            |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0033711821 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.625       |
# |    explained_variance   | 0.0921       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0543       |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00343     |
# |    value_loss           | 0.119        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.7        |
# |    ep_rew_mean          | 0.33        |
# | time/                   |             |
# |    fps                  | 668         |
# |    iterations           | 8           |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.004779153 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0466      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00559    |
# |    value_loss           | 0.119       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.3         |
# |    ep_rew_mean          | 0.38         |
# | time/                   |              |
# |    fps                  | 663          |
# |    iterations           | 9            |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0031082407 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0442       |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 0.119        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 0.52        |
# | time/                   |             |
# |    fps                  | 657         |
# |    iterations           | 10          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.003170824 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.457      |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0411      |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00443    |
# |    value_loss           | 0.118       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33           |
# |    ep_rew_mean          | 0.55         |
# | time/                   |              |
# |    fps                  | 652          |
# |    iterations           | 11           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0015247314 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.413       |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0489       |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 0.112        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.4         |
# |    ep_rew_mean          | 0.58         |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 12           |
# |    time_elapsed         | 304          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0015725979 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.365       |
# |    explained_variance   | 0.0836       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0489       |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 0.111        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.3         |
# |    ep_rew_mean          | 0.56         |
# | time/                   |              |
# |    fps                  | 642          |
# |    iterations           | 13           |
# |    time_elapsed         | 331          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0011887569 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.329       |
# |    explained_variance   | 0.0838       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.053        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 0.107        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.8        |
# |    ep_rew_mean          | 0.56        |
# | time/                   |             |
# |    fps                  | 639         |
# |    iterations           | 14          |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.001914179 |
# |    clip_fraction        | 0.0257      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.301      |
# |    explained_variance   | 0.0884      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.055       |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00252    |
# |    value_loss           | 0.108       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.3         |
# |    ep_rew_mean          | 0.63         |
# | time/                   |              |
# |    fps                  | 636          |
# |    iterations           | 15           |
# |    time_elapsed         | 386          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0014453309 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.281       |
# |    explained_variance   | 0.0863       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0307       |
# |    n_updates            | 88           |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 0.0965       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.2         |
# |    ep_rew_mean          | 0.6          |
# | time/                   |              |
# |    fps                  | 632          |
# |    iterations           | 16           |
# |    time_elapsed         | 414          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0013568653 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | 0.0888       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0452       |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 0.0957       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.1         |
# |    ep_rew_mean          | 0.66         |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 17           |
# |    time_elapsed         | 442          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0012825609 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.209       |
# |    explained_variance   | 0.0805       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0493       |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 0.0852       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.4         |
# |    ep_rew_mean          | 0.7          |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 18           |
# |    time_elapsed         | 470          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0011001064 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.192       |
# |    explained_variance   | 0.0706       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0356       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 0.0886       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 45            |
# |    ep_rew_mean          | 0.62          |
# | time/                   |               |
# |    fps                  | 624           |
# |    iterations           | 19            |
# |    time_elapsed         | 498           |
# |    total_timesteps      | 311296        |
# | train/                  |               |
# |    approx_kl            | 0.00089032145 |
# |    clip_fraction        | 0.013         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.166        |
# |    explained_variance   | 0.0587        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0319        |
# |    n_updates            | 104           |
# |    policy_gradient_loss | -0.00118      |
# |    value_loss           | 0.08          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 38.2          |
# |    ep_rew_mean          | 0.72          |
# | time/                   |               |
# |    fps                  | 623           |
# |    iterations           | 20            |
# |    time_elapsed         | 525           |
# |    total_timesteps      | 327680        |
# | train/                  |               |
# |    approx_kl            | 0.00082660053 |
# |    clip_fraction        | 0.0112        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.151        |
# |    explained_variance   | 0.0726        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0395        |
# |    n_updates            | 108           |
# |    policy_gradient_loss | -0.000411     |
# |    value_loss           | 0.0762        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.5         |
# |    ep_rew_mean          | 0.72         |
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 21           |
# |    time_elapsed         | 552          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0010349073 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.129       |
# |    explained_variance   | 0.0683       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0319       |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.00061     |
# |    value_loss           | 0.0728       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.4         |
# |    ep_rew_mean          | 0.74         |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 22           |
# |    time_elapsed         | 580          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0005541791 |
# |    clip_fraction        | 0.00865      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.132       |
# |    explained_variance   | 0.0678       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0405       |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -9.22e-05    |
# |    value_loss           | 0.0702       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 39.2          |
# |    ep_rew_mean          | 0.66          |
# | time/                   |               |
# |    fps                  | 619           |
# |    iterations           | 23            |
# |    time_elapsed         | 608           |
# |    total_timesteps      | 376832        |
# | train/                  |               |
# |    approx_kl            | 0.00062914257 |
# |    clip_fraction        | 0.00941       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.115        |
# |    explained_variance   | 0.0714        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0427        |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000737     |
# |    value_loss           | 0.0795        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.3         |
# |    ep_rew_mean          | 0.71         |
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 24           |
# |    time_elapsed         | 635          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0006615604 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.108       |
# |    explained_variance   | 0.0789       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0412       |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.000349    |
# |    value_loss           | 0.0725       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 37.9          |
# |    ep_rew_mean          | 0.67          |
# | time/                   |               |
# |    fps                  | 616           |
# |    iterations           | 25            |
# |    time_elapsed         | 663           |
# |    total_timesteps      | 409600        |
# | train/                  |               |
# |    approx_kl            | 0.00056351704 |
# |    clip_fraction        | 0.00862       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.107        |
# |    explained_variance   | 0.0934        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0196        |
# |    n_updates            | 128           |
# |    policy_gradient_loss | -0.000124     |
# |    value_loss           | 0.0712        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.6         |
# |    ep_rew_mean          | 0.73         |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 26           |
# |    time_elapsed         | 690          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0006759395 |
# |    clip_fraction        | 0.00829      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.1         |
# |    explained_variance   | 0.0672       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0403       |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000218    |
# |    value_loss           | 0.0805       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.5         |
# |    ep_rew_mean          | 0.74         |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 27           |
# |    time_elapsed         | 718          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0004723926 |
# |    clip_fraction        | 0.00645      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0795      |
# |    explained_variance   | 0.082        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0326       |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.000231    |
# |    value_loss           | 0.0645       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 37.8          |
# |    ep_rew_mean          | 0.74          |
# | time/                   |               |
# |    fps                  | 616           |
# |    iterations           | 28            |
# |    time_elapsed         | 744           |
# |    total_timesteps      | 458752        |
# | train/                  |               |
# |    approx_kl            | 0.00073189934 |
# |    clip_fraction        | 0.0087        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0831       |
# |    explained_variance   | 0.0662        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0498        |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000476     |
# |    value_loss           | 0.0703        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.4         |
# |    ep_rew_mean          | 0.7          |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 29           |
# |    time_elapsed         | 771          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0006519469 |
# |    clip_fraction        | 0.00945      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0776      |
# |    explained_variance   | 0.0917       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.037        |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.000456    |
# |    value_loss           | 0.0664       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.2        |
# |    ep_rew_mean          | 0.72        |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 30          |
# |    time_elapsed         | 798         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.000575001 |
# |    clip_fraction        | 0.00964     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0695     |
# |    explained_variance   | 0.0717      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0288      |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.000344   |
# |    value_loss           | 0.0702      |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 42.2          |
# |    ep_rew_mean          | 0.65          |
# | time/                   |               |
# |    fps                  | 614           |
# |    iterations           | 31            |
# |    time_elapsed         | 826           |
# |    total_timesteps      | 507904        |
# | train/                  |               |
# |    approx_kl            | 0.00028672777 |
# |    clip_fraction        | 0.00487       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0597       |
# |    explained_variance   | 0.0625        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0355        |
# |    n_updates            | 152           |
# |    policy_gradient_loss | -2.71e-05     |
# |    value_loss           | 0.0762        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 48.6          |
# |    ep_rew_mean          | 0.64          |
# | time/                   |               |
# |    fps                  | 613           |
# |    iterations           | 32            |
# |    time_elapsed         | 854           |
# |    total_timesteps      | 524288        |
# | train/                  |               |
# |    approx_kl            | 0.00035916216 |
# |    clip_fraction        | 0.00638       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0565       |
# |    explained_variance   | 0.0628        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0255        |
# |    n_updates            | 156           |
# |    policy_gradient_loss | -0.000121     |
# |    value_loss           | 0.075         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 44.9          |
# |    ep_rew_mean          | 0.66          |
# | time/                   |               |
# |    fps                  | 612           |
# |    iterations           | 33            |
# |    time_elapsed         | 883           |
# |    total_timesteps      | 540672        |
# | train/                  |               |
# |    approx_kl            | 0.00044791357 |
# |    clip_fraction        | 0.00624       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0635       |
# |    explained_variance   | 0.0617        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0506        |
# |    n_updates            | 160           |
# |    policy_gradient_loss | 3.07e-05      |
# |    value_loss           | 0.0664        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 46.8          |
# |    ep_rew_mean          | 0.75          |
# | time/                   |               |
# |    fps                  | 611           |
# |    iterations           | 34            |
# |    time_elapsed         | 911           |
# |    total_timesteps      | 557056        |
# | train/                  |               |
# |    approx_kl            | 0.00048588487 |
# |    clip_fraction        | 0.00552       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0531       |
# |    explained_variance   | 0.0603        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0405        |
# |    n_updates            | 164           |
# |    policy_gradient_loss | -0.00011      |
# |    value_loss           | 0.0704        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.6         |
# |    ep_rew_mean          | 0.68         |
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 35           |
# |    time_elapsed         | 940          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0006544949 |
# |    clip_fraction        | 0.00737      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0543      |
# |    explained_variance   | 0.0743       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0266       |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -3.22e-05    |
# |    value_loss           | 0.0604       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 43.6          |
# |    ep_rew_mean          | 0.67          |
# | time/                   |               |
# |    fps                  | 609           |
# |    iterations           | 36            |
# |    time_elapsed         | 967           |
# |    total_timesteps      | 589824        |
# | train/                  |               |
# |    approx_kl            | 0.00043425255 |
# |    clip_fraction        | 0.00484       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0519       |
# |    explained_variance   | 0.0718        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0404        |
# |    n_updates            | 172           |
# |    policy_gradient_loss | 2.09e-05      |
# |    value_loss           | 0.0691        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 44            |
# |    ep_rew_mean          | 0.7           |
# | time/                   |               |
# |    fps                  | 609           |
# |    iterations           | 37            |
# |    time_elapsed         | 993           |
# |    total_timesteps      | 606208        |
# | train/                  |               |
# |    approx_kl            | 0.00039331926 |
# |    clip_fraction        | 0.00543       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0521       |
# |    explained_variance   | 0.0765        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.027         |
# |    n_updates            | 176           |
# |    policy_gradient_loss | 7.16e-05      |
# |    value_loss           | 0.0692        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 43.1          |
# |    ep_rew_mean          | 0.67          |
# | time/                   |               |
# |    fps                  | 609           |
# |    iterations           | 38            |
# |    time_elapsed         | 1021          |
# |    total_timesteps      | 622592        |
# | train/                  |               |
# |    approx_kl            | 0.00044495048 |
# |    clip_fraction        | 0.00598       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0511       |
# |    explained_variance   | 0.0495        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0323        |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00019      |
# |    value_loss           | 0.0716        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 42.3          |
# |    ep_rew_mean          | 0.72          |
# | time/                   |               |
# |    fps                  | 609           |
# |    iterations           | 39            |
# |    time_elapsed         | 1048          |
# |    total_timesteps      | 638976        |
# | train/                  |               |
# |    approx_kl            | 0.00043812516 |
# |    clip_fraction        | 0.005         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0527       |
# |    explained_variance   | 0.0626        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0284        |
# |    n_updates            | 184           |
# |    policy_gradient_loss | -1.34e-05     |
# |    value_loss           | 0.0736        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 41.7          |
# |    ep_rew_mean          | 0.66          |
# | time/                   |               |
# |    fps                  | 608           |
# |    iterations           | 40            |
# |    time_elapsed         | 1076          |
# |    total_timesteps      | 655360        |
# | train/                  |               |
# |    approx_kl            | 0.00038029923 |
# |    clip_fraction        | 0.00473       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.043        |
# |    explained_variance   | 0.0571        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.042         |
# |    n_updates            | 188           |
# |    policy_gradient_loss | -0.00012      |
# |    value_loss           | 0.069         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.7         |
# |    ep_rew_mean          | 0.74         |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 41           |
# |    time_elapsed         | 1103         |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0006185132 |
# |    clip_fraction        | 0.00638      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.044       |
# |    explained_variance   | 0.0407       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0513       |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.000302    |
# |    value_loss           | 0.0748       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.4         |
# |    ep_rew_mean          | 0.64         |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 42           |
# |    time_elapsed         | 1131         |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0014128925 |
# |    clip_fraction        | 0.00555      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0422      |
# |    explained_variance   | 0.0634       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0821       |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.000416    |
# |    value_loss           | 0.0715       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 40.4          |
# |    ep_rew_mean          | 0.71          |
# | time/                   |               |
# |    fps                  | 607           |
# |    iterations           | 43            |
# |    time_elapsed         | 1160          |
# |    total_timesteps      | 704512        |
# | train/                  |               |
# |    approx_kl            | 0.00048095884 |
# |    clip_fraction        | 0.00626       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0455       |
# |    explained_variance   | 0.104         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.037         |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -7.6e-05      |
# |    value_loss           | 0.0714        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.5         |
# |    ep_rew_mean          | 0.69         |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 44           |
# |    time_elapsed         | 1187         |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0010547146 |
# |    clip_fraction        | 0.00705      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.039       |
# |    explained_variance   | 0.0938       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0344       |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.00058     |
# |    value_loss           | 0.0762       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 41.6          |
# |    ep_rew_mean          | 0.64          |
# | time/                   |               |
# |    fps                  | 606           |
# |    iterations           | 45            |
# |    time_elapsed         | 1215          |
# |    total_timesteps      | 737280        |
# | train/                  |               |
# |    approx_kl            | 0.00036717244 |
# |    clip_fraction        | 0.0047        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0343       |
# |    explained_variance   | 0.0899        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0465        |
# |    n_updates            | 208           |
# |    policy_gradient_loss | -0.000121     |
# |    value_loss           | 0.0711        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 41.8          |
# |    ep_rew_mean          | 0.69          |
# | time/                   |               |
# |    fps                  | 606           |
# |    iterations           | 46            |
# |    time_elapsed         | 1242          |
# |    total_timesteps      | 753664        |
# | train/                  |               |
# |    approx_kl            | 0.00030054193 |
# |    clip_fraction        | 0.00343       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0269       |
# |    explained_variance   | 0.0722        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0364        |
# |    n_updates            | 212           |
# |    policy_gradient_loss | -3.86e-06     |
# |    value_loss           | 0.0696        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 45.8          |
# |    ep_rew_mean          | 0.69          |
# | time/                   |               |
# |    fps                  | 605           |
# |    iterations           | 47            |
# |    time_elapsed         | 1270          |
# |    total_timesteps      | 770048        |
# | train/                  |               |
# |    approx_kl            | 0.00029090018 |
# |    clip_fraction        | 0.0034        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0273       |
# |    explained_variance   | 0.0574        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0275        |
# |    n_updates            | 216           |
# |    policy_gradient_loss | 0.000124      |
# |    value_loss           | 0.0617        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 38.7          |
# |    ep_rew_mean          | 0.66          |
# | time/                   |               |
# |    fps                  | 605           |
# |    iterations           | 48            |
# |    time_elapsed         | 1298          |
# |    total_timesteps      | 786432        |
# | train/                  |               |
# |    approx_kl            | 0.00020994317 |
# |    clip_fraction        | 0.00331       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0291       |
# |    explained_variance   | 0.0524        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0438        |
# |    n_updates            | 220           |
# |    policy_gradient_loss | 0.000102      |
# |    value_loss           | 0.0651        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.6         |
# |    ep_rew_mean          | 0.77         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 49           |
# |    time_elapsed         | 1325         |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0008393044 |
# |    clip_fraction        | 0.00323      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0265      |
# |    explained_variance   | 0.0666       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.043        |
# |    n_updates            | 224          |
# |    policy_gradient_loss | 2.03e-05     |
# |    value_loss           | 0.0577       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 40.2          |
# |    ep_rew_mean          | 0.74          |
# | time/                   |               |
# |    fps                  | 605           |
# |    iterations           | 50            |
# |    time_elapsed         | 1352          |
# |    total_timesteps      | 819200        |
# | train/                  |               |
# |    approx_kl            | 0.00057553453 |
# |    clip_fraction        | 0.00591       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0286       |
# |    explained_variance   | 0.0825        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0408        |
# |    n_updates            | 228           |
# |    policy_gradient_loss | -0.000465     |
# |    value_loss           | 0.0708        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 39            |
# |    ep_rew_mean          | 0.75          |
# | time/                   |               |
# |    fps                  | 606           |
# |    iterations           | 51            |
# |    time_elapsed         | 1378          |
# |    total_timesteps      | 835584        |
# | train/                  |               |
# |    approx_kl            | 0.00074076967 |
# |    clip_fraction        | 0.00519       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0355       |
# |    explained_variance   | 0.0928        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0336        |
# |    n_updates            | 232           |
# |    policy_gradient_loss | -0.000223     |
# |    value_loss           | 0.0637        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 41.1          |
# |    ep_rew_mean          | 0.74          |
# | time/                   |               |
# |    fps                  | 605           |
# |    iterations           | 52            |
# |    time_elapsed         | 1406          |
# |    total_timesteps      | 851968        |
# | train/                  |               |
# |    approx_kl            | 0.00042010364 |
# |    clip_fraction        | 0.0045        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0287       |
# |    explained_variance   | 0.0585        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0179        |
# |    n_updates            | 236           |
# |    policy_gradient_loss | -8.27e-05     |
# |    value_loss           | 0.0629        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.8         |
# |    ep_rew_mean          | 0.74         |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 53           |
# |    time_elapsed         | 1432         |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0002918461 |
# |    clip_fraction        | 0.00366      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0274      |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0385       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 6.01e-05     |
# |    value_loss           | 0.057        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 43.1          |
# |    ep_rew_mean          | 0.77          |
# | time/                   |               |
# |    fps                  | 606           |
# |    iterations           | 54            |
# |    time_elapsed         | 1458          |
# |    total_timesteps      | 884736        |
# | train/                  |               |
# |    approx_kl            | 0.00033644913 |
# |    clip_fraction        | 0.00407       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0255       |
# |    explained_variance   | 0.0892        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0488        |
# |    n_updates            | 244           |
# |    policy_gradient_loss | -0.000154     |
# |    value_loss           | 0.0716        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 39            |
# |    ep_rew_mean          | 0.82          |
# | time/                   |               |
# |    fps                  | 606           |
# |    iterations           | 55            |
# |    time_elapsed         | 1485          |
# |    total_timesteps      | 901120        |
# | train/                  |               |
# |    approx_kl            | 0.00034459587 |
# |    clip_fraction        | 0.00404       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0298       |
# |    explained_variance   | 0.0513        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0212        |
# |    n_updates            | 248           |
# |    policy_gradient_loss | 0.000166      |
# |    value_loss           | 0.0646        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 41.7          |
# |    ep_rew_mean          | 0.76          |
# | time/                   |               |
# |    fps                  | 606           |
# |    iterations           | 56            |
# |    time_elapsed         | 1512          |
# |    total_timesteps      | 917504        |
# | train/                  |               |
# |    approx_kl            | 0.00021657794 |
# |    clip_fraction        | 0.00206       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0242       |
# |    explained_variance   | 0.0801        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.037         |
# |    n_updates            | 252           |
# |    policy_gradient_loss | 0.000183      |
# |    value_loss           | 0.0665        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 42.1          |
# |    ep_rew_mean          | 0.73          |
# | time/                   |               |
# |    fps                  | 606           |
# |    iterations           | 57            |
# |    time_elapsed         | 1540          |
# |    total_timesteps      | 933888        |
# | train/                  |               |
# |    approx_kl            | 0.00035273144 |
# |    clip_fraction        | 0.00284       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0258       |
# |    explained_variance   | 0.0687        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0317        |
# |    n_updates            | 256           |
# |    policy_gradient_loss | 5.94e-05      |
# |    value_loss           | 0.0573        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 41.8          |
# |    ep_rew_mean          | 0.7           |
# | time/                   |               |
# |    fps                  | 606           |
# |    iterations           | 58            |
# |    time_elapsed         | 1567          |
# |    total_timesteps      | 950272        |
# | train/                  |               |
# |    approx_kl            | 0.00040205196 |
# |    clip_fraction        | 0.00439       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0325       |
# |    explained_variance   | 0.0642        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0395        |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.00013      |
# |    value_loss           | 0.0629        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 45.5          |
# |    ep_rew_mean          | 0.7           |
# | time/                   |               |
# |    fps                  | 605           |
# |    iterations           | 59            |
# |    time_elapsed         | 1595          |
# |    total_timesteps      | 966656        |
# | train/                  |               |
# |    approx_kl            | 0.00039337634 |
# |    clip_fraction        | 0.00424       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0332       |
# |    explained_variance   | 0.0584        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0292        |
# |    n_updates            | 264           |
# |    policy_gradient_loss | 7.54e-06      |
# |    value_loss           | 0.0651        |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.7        |
# |    ep_rew_mean          | 0.73        |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 60          |
# |    time_elapsed         | 1622        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.005610618 |
# |    clip_fraction        | 0.00806     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0339     |
# |    explained_variance   | 0.0642      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0336      |
# |    n_updates            | 268         |
# |    policy_gradient_loss | -0.00112    |
# |    value_loss           | 0.0741      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43           |
# |    ep_rew_mean          | 0.74         |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 61           |
# |    time_elapsed         | 1650         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0007050087 |
# |    clip_fraction        | 0.00839      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0374      |
# |    explained_variance   | 0.0639       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0206       |
# |    n_updates            | 272          |
# |    policy_gradient_loss | -0.000338    |
# |    value_loss           | 0.0711       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 40            |
# |    ep_rew_mean          | 0.73          |
# | time/                   |               |
# |    fps                  | 605           |
# |    iterations           | 62            |
# |    time_elapsed         | 1677          |
# |    total_timesteps      | 1015808       |
# | train/                  |               |
# |    approx_kl            | 0.00042334368 |
# |    clip_fraction        | 0.00539       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0331       |
# |    explained_variance   | 0.0585        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0217        |
# |    n_updates            | 276           |
# |    policy_gradient_loss | -0.000327     |
# |    value_loss           | 0.0793        |
# -------------------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# Evaluate Model
model = PPO.load(
    path="./ppo-FrozenLake-v1",
    device="cpu")
eval_env = Monitor(gym.make("FrozenLake-v1", render_mode='rgb_array'))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=100, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=0.69 +/- 0.46249324319388707

# %% [markdown]
# # Q-Learning: FrozenLake-v1

# %%
# train
def train(args, env, Q_Table, action_masked=False):    
    for episode in tqdm(range(1, args["num_episode"]+1)):
        epsilon = args["min_epsilon"] + (
            args["max_epsilon"] - args["min_epsilon"]) * np.exp(- args["decay_rate"] * episode)
        
        t = 1
        s_t, info = env.reset()
        
        action_mask = None
        if action_masked:
            action_mask = info["action_mask"]
            
        while t <= args["max_steps"]:
            # epsilon-Greedy select one action a_t
            # print(np.where(info["action_mask"] == 1)[0])
            if action_masked:
                actions = np.where(action_mask == 1)[0]
            else:
                actions = np.arange(Q_Table.shape[1])
                
            if np.random.rand(1)[0] < epsilon:
                a_t_index = np.random.randint(0, actions.shape[0])
                a_t = actions[a_t_index]
                
            else: 
                a_t_index = np.argmax(Q_Table[s_t, actions])
                a_t = actions[a_t_index]
            # print("actions: ", actions, " action:", a_t)
            
            # execute action a_t, get reward r_t and state s_t+1
            s_t1, r_t, terminated, truncated, info = env.step(a_t)
            # if r_t > 0:
            #     print(r_t)
            
            if action_masked:
                action_mask = info["action_mask"]
                actions_t1 = np.where(action_mask == 1)[0]
            else:
                actions_t1 = np.arange(Q_Table.shape[1])

            # Greedy select optimal action, update Q-Table
            Q_Table[s_t][a_t] = Q_Table[s_t][a_t] - args["lr"] * (
                Q_Table[s_t][a_t] - (r_t + args["Gamma"] * np.max(Q_Table[s_t1, actions_t1]))) 
            
            if terminated or truncated:
                break
            
            t = t + 1
            s_t = s_t1
            
    return Q_Table

# %%
# evaluate
def evaluate(args, env, Q_Table, episode):
    returns = [] 
    
    for _ in range(episode):
        cumulReward = 0
        t = 1
        s_t, info = env.reset()
        
        while t <= args["max_steps"]:
            # Evaluation Stage: Greedy select one action a_t
            a_t = np.argmax(Q_Table[s_t])
            
            # execute action a_t, get reward r_t and state s_t+1
            s_t1, r_t, terminated, truncated, info = env.step(a_t)
            cumulReward += r_t
            if terminated or truncated:
                break
            
            t = t + 1
            s_t = s_t1
    
        returns.append(cumulReward)

    return np.mean(returns), np.std(returns)

# %%
# Edit args
args = {
    "min_epsilon": 0.05,
    "max_epsilon": 1.0,
    "decay_rate": 0.0005, 
    "lr": 0.1,
    "Gamma": 1,
    "num_episode": 1000,
    "max_steps": 100
}

# Initializ env and QTable
env = gym.make('FrozenLake-v1', desc=None, map_name="4x4", is_slippery=True)
Q_Table_lake = np.zeros((4*4, 4))  # 对应 4x4 的 map，大小为 4 的动作空间
# Q_Table_lake = np.load("Q_Table_FrozenLake-v1.npy")

# Train and Evaluate
Q_Table_lake = train(args, env, Q_Table_lake, False)
mean, std = evaluate(args, env, Q_Table_lake, 200)

# Visualize results
print("return: ", mean, " +/- ", std)
print(Q_Table_lake)

# Save QTable
np.save('Q_Table_FrozenLake-v1.npy', Q_Table_lake)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 845.56it/s]
# return:  0.7  +/-  0.458257569495584
# [[0.15565764 0.14476262 0.12950701 0.13043506]
#  [0.05144439 0.08370384 0.05384178 0.1162699 ]
#  [0.09442068 0.05603651 0.06188814 0.04557425]
#  [0.01310573 0.02438691 0.01241492 0.04033215]
#  [0.16055545 0.07958989 0.11431602 0.09357792]
#  [0.         0.         0.         0.        ]
#  [0.0839196  0.06588115 0.10805837 0.01147486]
#  [0.         0.         0.         0.        ]
#  [0.10311557 0.09491515 0.10684695 0.17468506]
#  [0.12979347 0.20368354 0.15911093 0.15775257]
#  [0.37011264 0.08312436 0.13431494 0.04757376]
#  [0.         0.         0.         0.        ]
#  [0.         0.         0.         0.        ]
#  [0.09799039 0.15211731 0.2374934  0.18624435]
#  [0.34687268 0.57080549 0.37214129 0.41626629]
#  [0.         0.         0.         0.        ]]

# %% [markdown]
# # Q-Learning: Taxi-v3

# %%
# Edit args
args = {
    "max_epsilon": 1.0,
    "min_epsilon": 0.05,
    "decay_rate": 0.0005
    , 
    "lr": 0.2,
    "Gamma": 1,
    
    "num_episode": 25000,
    "max_steps": 25
}

# Initializ env and QTable
env = gym.make('Taxi-v3')
Q_Table_taxi = np.zeros((env.observation_space.n, env.action_space.n)) 
# Q_Table_lake = np.load("Q_Table_FrozenLake-v1.npy")

# Train and Evaluate
Q_Table_taxi = train(args, env, Q_Table_taxi, True)
mean, std = evaluate(args, env, Q_Table_taxi, 100)

# Visualize results
print("return: ", mean, " +/- ", std)
print(Q_Table_taxi)

# Save QTable
np.save('Q_Table_Taxi-v3.npy', Q_Table_taxi)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 25000/25000 [01:05<00:00, 380.93it/s]
# return:  7.9  +/-  2.487971060924946
# [[ 0.          0.          0.          0.          0.          0.        ]
#  [ 8.99938372  0.          8.99792349  0.         11.          0.        ]
#  [12.99999774  0.         12.99999793  0.         15.          0.        ]
#  ...
#  [ 0.          6.79142462  0.         13.99999364  0.          0.        ]
#  [ 0.         -0.20976383  0.         11.99999522  0.          0.        ]
#  [ 0.         15.80828339  0.         19.          0.          0.        ]]
